# %% [markdown]
# ##  Polynomials
# NumPy also contains polynomials in different bases:
#
# For example, 3x^2 + 2x - 1

# %%
import numpy as np

p = np.poly1d([3, 2, -1])
p[0]
# Out:
# -1

# %%
p.roots
# Out:
# array([-1.        ,  0.33333333])

# %%
p.order
# Out:
# 2

# %%
x = np.linspace(0, 1, 20)
x
# Out:
# array([ 0.        ,  0.05263158,  0.10526316,  0.15789474,  0.21052632,
#         0.26315789,  0.31578947,  0.36842105,  0.42105263,  0.47368421,
#         0.52631579,  0.57894737,  0.63157895,  0.68421053,  0.73684211,
#         0.78947368,  0.84210526,  0.89473684,  0.94736842,  1.        ])

# %%
y = np.cos(x) + 0.3*np.random.rand(20)
y
# Out:
# array([ 1.10456362,  1.1540859 ,  1.14397254,  1.13789721,  1.07221409,
#         1.16501133,  0.99169828,  1.19322645,  1.0871037 ,  0.93565865,
#         0.89897641,  1.06220298,  1.0142884 ,  0.8279157 ,  1.00986904,
#         0.89550231,  0.74612293,  0.79879652,  0.82311942,  0.83463829])

# %%
p = np.poly1d(np.polyfit(x, y, 3))
p
# Out:
# poly1d([ 0.77051463, -1.35888002,  0.27484371,  1.11953433])

# %%
t = np.linspace(0, 1, 200)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x, y, 'o', t, p(t), '-')

# %% [markdown]
# ## More polynomials (with more bases)
# NumPy also has a more sophisticated polynomial interface, which supports e.g. the Chebyshev basis.
#
# 3x^2 + 2x - 1:

# %%
p = np.polynomial.Polynomial([-1, 2, 3])
p
# Out:
# Polynomial([-1.,  2.,  3.], [-1,  1], [-1,  1])

# %%
p(0)
# Out:
# -1.0

# %%
p.roots()
# Out:
# array([-1.        ,  0.33333333])

# %%
p.degree()
# Out:
# 2

# %% [markdown]
# **Example using polynomials in Chebyshev basis, for polynomials in range [-1, 1]:**

# %%
x = np.linspace(-1, 1, 2000)
y = np.cos(x) + 0.3*np.random.rand(2000)

p = np.polynomial.Chebyshev.fit(x, y, 90)

t = np.linspace(-1, 1, 200)

plt.plot(x, y, 'r')

# %%
plt.plot(t, p(t), 'k-', lw=3)

# %%
plt.plot(x, y, 'r')
plt.plot(t, p(t), 'k-', lw=3)

# %% [markdown]
# The Chebyshev polynomials have some advantages in interpolation.

# %% [markdown]
# ## Loading data files

# %% [markdown]
# ### Text files

# %%
data = np.loadtxt('data/populations.txt')
data
# Out:
# array([[  1900.,  30000.,   4000.,  48300.],
#        [  1901.,  47200.,   6100.,  48200.],
#        [  1902.,  70200.,   9800.,  41500.],
#        [  1903.,  77400.,  35200.,  38200.],
#        [  1904.,  36300.,  59400.,  40600.],
#        [  1905.,  20600.,  41700.,  39800.],
#        [  1906.,  18100.,  19000.,  38600.],
#        [  1907.,  21400.,  13000.,  42300.],
#        [  1908.,  22000.,   8300.,  44500.],
#        [  1909.,  25400.,   9100.,  42100.],
#        [  1910.,  27100.,   7400.,  46000.],
#        [  1911.,  40300.,   8000.,  46800.],
#        [  1912.,  57000.,  12300.,  43800.],
#        [  1913.,  76600.,  19500.,  40900.],
#        [  1914.,  52300.,  45700.,  39400.],
#        [  1915.,  19500.,  51100.,  39000.],
#        [  1916.,  11200.,  29700.,  36700.],
#        [  1917.,   7600.,  15800.,  41800.],
#        [  1918.,  14600.,   9700.,  43300.],
#        [  1919.,  16200.,  10100.,  41300.],
#        [  1920.,  24700.,   8600.,  47300.]])

# %%
np.savetxt('data/pop2.txt', data)

# %%
data2 = np.loadtxt('data/pop2.txt')
data2
# Out:
# array([[  1900.,  30000.,   4000.,  48300.],
#        [  1901.,  47200.,   6100.,  48200.],
#        [  1902.,  70200.,   9800.,  41500.],
#        [  1903.,  77400.,  35200.,  38200.],
#        [  1904.,  36300.,  59400.,  40600.],
#        [  1905.,  20600.,  41700.,  39800.],
#        [  1906.,  18100.,  19000.,  38600.],
#        [  1907.,  21400.,  13000.,  42300.],
#        [  1908.,  22000.,   8300.,  44500.],
#        [  1909.,  25400.,   9100.,  42100.],
#        [  1910.,  27100.,   7400.,  46000.],
#        [  1911.,  40300.,   8000.,  46800.],
#        [  1912.,  57000.,  12300.,  43800.],
#        [  1913.,  76600.,  19500.,  40900.],
#        [  1914.,  52300.,  45700.,  39400.],
#        [  1915.,  19500.,  51100.,  39000.],
#        [  1916.,  11200.,  29700.,  36700.],
#        [  1917.,   7600.,  15800.,  41800.],
#        [  1918.,  14600.,   9700.,  43300.],
#        [  1919.,  16200.,  10100.,  41300.],
#        [  1920.,  24700.,   8600.,  47300.]])

# %%
pwd
# Out:
# 'C:\\Users\\Sourav\\For_GitHub_Repos\\DataScience_Python\\Numpy'

# %%
cd data
# Out:
# C:\Users\Sourav\For_GitHub_Repos\DataScience_Python\Numpy\data

# %%
ls
# Out:
#  Volume in drive C is PRIME
#  Volume Serial Number is 948E-1F83
#
#  Directory of C:\Users\Sourav\For_GitHub_Repos\DataScience_Python\Numpy\data
#
# 26-01-2018  04:20 PM    <DIR>          .
# 26-01-2018  04:20 PM    <DIR>          ..
# 26-01-2018  04:17 PM    <DIR>          .ipynb_checkpoints
# 26-01-2018  04:20 PM             2,100 pop2.txt
# 26-01-2018  04:17 PM               525 populations.txt
#                2 File(s)          2,625 bytes
#                3 Dir(s)  30,060,187,648 bytes free

# %% [markdown]
# ### Images
# Using Matplotlib:

# %%
cd ..
# Out:
# C:\Users\Sourav\For_GitHub_Repos\DataScience_Python\Numpy

# %%
img = plt.imread('data/elephant.png')

# %%
img.shape, img.dtype
# Out:
# ((600, 800, 4), dtype('float32'))

# %%
plt.imshow(img)

# %%
plt.savefig('data/elephant_plot.png')

# %%
plt.imsave('data/gray_elephant.png', img[:,:,0], cmap=plt.cm.gray)

# %%
plt.imshow(plt.imread('data/gray_elephant.png'))

# %%
plt.imsave('data/tiny_elephant.png', img[::6,::6])
plt.imshow(plt.imread('data/tiny_elephant.png'), interpolation='nearest')

# %% [markdown]
# **Exercise: Text data files** <br>
#
# Write a Python script that loads data from populations.txt:: and drop the last column and the first 5 rows. Save the smaller dataset to pop3.txt.

# %%
data
# Out:
# array([[  1900.,  30000.,   4000.,  48300.],
#        [  1901.,  47200.,   6100.,  48200.],
#        [  1902.,  70200.,   9800.,  41500.],
#        [  1903.,  77400.,  35200.,  38200.],
#        [  1904.,  36300.,  59400.,  40600.],
#        [  1905.,  20600.,  41700.,  39800.],
#        [  1906.,  18100.,  19000.,  38600.],
#        [  1907.,  21400.,  13000.,  42300.],
#        [  1908.,  22000.,   8300.,  44500.],
#        [  1909.,  25400.,   9100.,  42100.],
#        [  1910.,  27100.,   7400.,  46000.],
#        [  1911.,  40300.,   8000.,  46800.],
#        [  1912.,  57000.,  12300.,  43800.],
#        [  1913.,  76600.,  19500.,  40900.],
#        [  1914.,  52300.,  45700.,  39400.],
#        [  1915.,  19500.,  51100.,  39000.],
#        [  1916.,  11200.,  29700.,  36700.],
#        [  1917.,   7600.,  15800.,  41800.],
#        [  1918.,  14600.,   9700.,  43300.],
#        [  1919.,  16200.,  10100.,  41300.],
#        [  1920.,  24700.,   8600.,  47300.]])

# %%
data3 = data.T
data3
# Out:
# array([[  1900.,   1901.,   1902.,   1903.,   1904.,   1905.,   1906.,
#           1907.,   1908.,   1909.,   1910.,   1911.,   1912.,   1913.,
#           1914.,   1915.,   1916.,   1917.,   1918.,   1919.,   1920.],
#        [ 30000.,  47200.,  70200.,  77400.,  36300.,  20600.,  18100.,
#          21400.,  22000.,  25400.,  27100.,  40300.,  57000.,  76600.,
#          52300.,  19500.,  11200.,   7600.,  14600.,  16200.,  24700.],
#        [  4000.,   6100.,   9800.,  35200.,  59400.,  41700.,  19000.,
#          13000.,   8300.,   9100.,   7400.,   8000.,  12300.,  19500.,
#          45700.,  51100.,  29700.,  15800.,   9700.,  10100.,   8600.],
#        [ 48300.,  48200.,  41500.,  38200.,  40600.,  39800.,  38600.,
#          42300.,  44500.,  42100.,  46000.,  46800.,  43800.,  40900.,
#          39400.,  39000.,  36700.,  41800.,  43300.,  41300.,  47300.]])

# %%
data3 = data3[:-1]
data3
# Out:
# array([[  1900.,   1901.,   1902.,   1903.,   1904.,   1905.,   1906.,
#           1907.,   1908.,   1909.,   1910.,   1911.,   1912.,   1913.,
#           1914.,   1915.,   1916.,   1917.,   1918.,   1919.,   1920.],
#        [ 30000.,  47200.,  70200.,  77400.,  36300.,  20600.,  18100.,
#          21400.,  22000.,  25400.,  27100.,  40300.,  57000.,  76600.,
#          52300.,  19500.,  11200.,   7600.,  14600.,  16200.,  24700.],
#        [  4000.,   6100.,   9800.,  35200.,  59400.,  41700.,  19000.,
#          13000.,   8300.,   9100.,   7400.,   8000.,  12300.,  19500.,
#          45700.,  51100.,  29700.,  15800.,   9700.,  10100.,   8600.]])

# %%
data3 = data3.T
data3
# Out:
# array([[  1900.,  30000.,   4000.],
#        [  1901.,  47200.,   6100.],
#        [  1902.,  70200.,   9800.],
#        [  1903.,  77400.,  35200.],
#        [  1904.,  36300.,  59400.],
#        [  1905.,  20600.,  41700.],
#        [  1906.,  18100.,  19000.],
#        [  1907.,  21400.,  13000.],
#        [  1908.,  22000.,   8300.],
#        [  1909.,  25400.,   9100.],
#        [  1910.,  27100.,   7400.],
#        [  1911.,  40300.,   8000.],
#        [  1912.,  57000.,  12300.],
#        [  1913.,  76600.,  19500.],
#        [  1914.,  52300.,  45700.],
#        [  1915.,  19500.,  51100.],
#        [  1916.,  11200.,  29700.],
#        [  1917.,   7600.,  15800.],
#        [  1918.,  14600.,   9700.],
#        [  1919.,  16200.,  10100.],
#        [  1920.,  24700.,   8600.]])

# %%
data3 = data3[5:]
data3
# Out:
# array([[  1905.,  20600.,  41700.],
#        [  1906.,  18100.,  19000.],
#        [  1907.,  21400.,  13000.],
#        [  1908.,  22000.,   8300.],
#        [  1909.,  25400.,   9100.],
#        [  1910.,  27100.,   7400.],
#        [  1911.,  40300.,   8000.],
#        [  1912.,  57000.,  12300.],
#        [  1913.,  76600.,  19500.],
#        [  1914.,  52300.,  45700.],
#        [  1915.,  19500.,  51100.],
#        [  1916.,  11200.,  29700.],
#        [  1917.,   7600.,  15800.],
#        [  1918.,  14600.,   9700.],
#        [  1919.,  16200.,  10100.],
#        [  1920.,  24700.,   8600.]])

# %%
np.savetxt('data/pop3.txt', data3)
